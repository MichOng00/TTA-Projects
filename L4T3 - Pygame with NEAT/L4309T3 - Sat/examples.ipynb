# %%
people = ["Andy",  "Shun Bo", "Liam", "Michelle", "Andrew", "Abraham", "Hiro", "Cyllee", "Vyelle", "Sylvester"]
for i, person in enumerate(people):
    print(f"{person} is at position {i}")
# Out:
# Andy is at position 0
# Shun Bo is at position 1
# Liam is at position 2
# Michelle is at position 3
# Andrew is at position 4
# Abraham is at position 5
# Hiro is at position 6
# Cyllee is at position 7
# Vyelle is at position 8
# Sylvester is at position 9

# %%
print(people[0])
# Out:
# Andy

# %%
5 // 2 # floor division
# Out:
# 2

# %%
5 % 2 # modulo
# Out:
# 1
