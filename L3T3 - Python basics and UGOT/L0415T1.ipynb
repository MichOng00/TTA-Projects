# %% [markdown]
# # Session 1

# %%
print("hello")
# Out:
# hello

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
# this is a comment

# %%
this is a comment
# Out:
#   Cell In[7], line 1
#     this is a comment
#               ^
# SyntaxError: invalid syntax

# %%
# print("hello")

# %%
print("😭")
# Out:
# 😭

# %%
print(10000) # integer - whole number
print(type(1000))
print(type("hello")) # string - word
print(type(4.5)) # float - decimal number
print(type(True)) # boolean - True or False
# Out:
# 10000
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
print(2 + 2)
print(2 * 2) # multiply
print(2 - 2)
print(2 / 2) # division ALWAYS gives you a FLOAT
# Out:
# 4
# 4
# 0
# 1.0

# %%
print("Hello" + "World")
# Out:
# HelloWorld

# %%
# variables
age = 6
my_name = "Michelle"
print(age * age)
print(f"I am {my_name}") # formatted string (f-string)
print("I am {my_name}") # without the f
# Out:
# 36
# I am Michelle
# I am {my_name}

# %%
# exercise: create a variable for your hobby and print it in an f-string
