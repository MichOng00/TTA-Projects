# %% [markdown]
# # Session 2
# - defining functions
# - arm
# - camera
# - lists

# %%
# defining a function
def function_name():
    print("hello")
    print("have a nice day")

function_name()
# Out:
# hello
# have a nice day

# %%
# calling a function
function_name()
# Out:
# hello
# have a nice day

# %%
# functions with parameters
def func_params(param1, param2):
    print(param1, param2)

def greet(name):
    print(f"hello, {name}")

greet("Michelle")
# Out:
# hello, Michelle

# %%
def multiply_five(num):
    result = num * 5
    print(f"the result is {result}")

multiply_five(3)
# Out:
# the result is 15

# %%
def add_numbers(num1, num2):
    print(f"result is {num1+num2}")

add_numbers(5, 9)
# Out:
# result is 14

# %%
from ugot import ugot
got = ugot.UGOT()
got.initialize("192.168.88.1") # IP add
# Settings > About > IP address
import time

# %%
got.mechanical_clamp_release()
time.sleep(1)
got.mechanical_clamp_close()

# %%
# (joint1, jont2, joint3, runtime)
got.mechanical_joint_control(0, 0, 0, 500)

# %%
def pickup():
    # open gripper
    got.mechanical_clamp_release()
    time.sleep(1)
    # move arm down
    got.mechanical_joint_control(0, -45, -25, 600)
    time.sleep(1)
    # close gripper
    got.mechanical_clamp_close()
    time.sleep(1)
    # move arm back up
    got.mechanical_joint_control(0, 0, 0, 600)
pickup()

# %%
def throw():
    # move arm back
    got.mechanical_joint_control(...)
    time.sleep(1)
    # open gripper and move arm forward

# %%
while True:
    cmd = input("enter a command: ")
    if cmd == "quit":
        break # exit the loop
    if cmd == "w":
        got.mecanum_translate_speed_times(0, 40, 30, 1)
    if cmd == "s":
        got.mecanum_translate_speed_times(180, 40, 30, 1)
    if cmd == "a":
        got.mecanum_turn_speed_times(2, 50, 90, 2)
    if cmd == "d":
        got.mecanum_turn_speed_times(3, 50, 90, 2)
    if cmd == "pick":
        pickup()
    if cmd == "throw":
        throw()

# %%
pip install opencv-python numpy pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import numpy as np
import cv2
from ugot import ugot
got = ugot.UGOT()
got.initialize("192.168.88.1") # IP add
import time
got.open_camera()
got.load_models(["color_recognition"])
while True:
    frame = got.read_camera_data()
    nparr = np.frombuffer(frame, np.uint8)
    data = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    result = got.get_color_total_info()
    if result:
        color = result[0]
        cv2.putText(data, color, (20, 20), 0,
        1, (255, 255, 255), 3, cv2.LINE_AA)
    cv2.imshow("camera", data)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cv2.destroyAllWindows()

# %%
# lists
fruits = ["apple", "banana", "coconut"]
print(fruits[1])
# Out:
# banana
