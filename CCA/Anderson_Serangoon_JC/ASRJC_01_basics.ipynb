# %% [markdown]
# # Session 1

# %%
print("hello world")
# Out:
# hello world

# %%
# this is a comment
print(type("42")) # string
print(type(42)) # integer
print(type(42.0)) # float
print(type(True)) # boolean
print(type(False)) # boolean
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>

# %%
name = "Michelle"
print(name)
age = 100
print(name, age)
# formatted string
print(f"I am {name}, {age} years old")
# Out:
# Michelle
# Michelle 100
# I am Michelle, 100 years old

# %%
print() # call a function
name = "Michelle" # assign a variable

# %%
print('Simon says "Hi"')
print("Simon says 'hi'")
# Out:
# Simon says "Hi"
# Simon says 'hi'

# %%
# arithmetic operators
print(2 + 3)
print(2 - 3)
print(2 * 3) # integer
print(2 * 3.0) # float
print(2 / 2) # division always gives float
# Out:
# 5
# -1
# 6
# 6.0
# 1.0

# %%
num1 = 3
num2 = 5
print(num1 + num2)
# Out:
# 8

# %%
my_name2

# %%
str1 = "3"
str2 = "hello"
print(str1 + str2) # string concatenation
# Out:
# 3hello

# %%
num1 = 3
str1 = "hi"
print(num1 + str1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 num1 = 3
#       2 str1 = "hi"
# ----> 3 print(num1 + str1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num1 = 3
str1 = "hi"
print(num1 * str1)
# Out:
# hihihi

# %%
num1 = 3
num1 = num1 + 1
print(num1)
num1 += 2  # num1 = num1 + 2
print(num1)
# Out:
# 4
# 6

# %%
# conditionals
if True:
    print("the condition is true")
    print("hi")
if False:
    print("the condition is false")
    print("hi")
# Out:
# the condition is true
# hi

# %%
# comparison operators
print(8 < 10)
print(8 <= 10)
print(8 > 10)
print(8 == 10) # TWO equals signs
print(8 != 10) # not equal
# Python is case-sensitive
print("hello" == "HELLO") # False
# Out:
# True
# True
# False
# False
# True
# False

# %%
age = 19
if age >= 18:
    print("you can watch spiderman")
else:
    print("you can't watch spiderman")
# Out:
# you can watch spiderman

# %%
# exercise: write a program that tells
# you if you pass or fail based on
# your grade
grade = int(input("what is your grade"))
if grade >= 50:
    print("pass")
else:
    print("fail :(")
# Out:
# what is your grade 60
# pass

# %%
name = input("What is your name?")
age = input("What is your age?")
print(name, age)
# Out:
# What is your name? M
# What is your age? 42
# M 42

# %%
type(age)
type(int(age)) # int converts to integer
# Out:
# int

# %%
print(str(42))
print(float("3"))
# float("hello") # error
# Out:
# 42
# 3.0

# %%
from ugot import ugot
got = ugot.UGOT()
got.initialize("192.168.88.1")

# %%
got.mecanum_translate_speed_times(
    0, 30, 30, 1
) # angle, speed, distance, unit

# %%
got.mecanum_turn_speed_times(
    2, 40, 90, 2
) # direction, speed, angle, unit

got.mecanum_turn_speed_times(2, 40, 90, 2)

# %%
# drive in a square on the ground
got.mecanum_translate_speed_times(0, 30, 40, 1)
got.mecanum_turn_speed_times(2, 40, 90, 2)
got.mecanum_translate_speed_times(0, 30, 40, 1)
got.mecanum_turn_speed_times(2, 40, 90, 2)
got.mecanum_translate_speed_times(0, 30, 40, 1)
got.mecanum_turn_speed_times(2, 40, 90, 2)
got.mecanum_translate_speed_times(0, 30, 40, 1)
got.mecanum_turn_speed_times(2, 40, 90, 2)

# %%
# for loop
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for apple in range(3):
    print(apple)
# Out:
# 0
# 1
# 2

# %%
for i in range(4):
    got.mecanum_translate_speed_times(0, 30, 40, 1)
    got.mecanum_turn_speed_times(2, 40, 90, 2)

# %%
# drive in a triangle
for i in range(3):
    got.mecanum_translate_speed_times(0, 30, 40, 1)
    got.mecanum_turn_speed_times(2, 40, 120, 2)

# %%
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
password = ""
while password != "password123":
    password = input("enter password")
# Out:
# enter password 3
# enter password 4
# enter password pas
# enter password password123

# %%
while True:
    cmd = input("enter a letter: ")
    if cmd == "q":
        break # exit the loop
    if cmd == "w":
        got.mecanum_translate_speed_times(0, 40, 30, 1)
    if cmd == "s":
        got.mecanum_translate_speed_times(180, 40, 30, 1)
    # add your own
# Out:
# enter a letter:  a
# enter a letter:  hi
# enter a letter:  q

# %%
while False:
    print("hi")

# %%
import time
got.mecanum_move_xyz(0, 0, 0)
time.sleep(2)  # wait 2 seconds
got.mecanum_stop()
