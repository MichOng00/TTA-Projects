# %%
# NB: Python version must be between 3.6.6 and 3.8.9
# use Anaconda to create new environment with Python 3.7.x, then lauch Jupyter notebook from the 
# !pip install robomaster
# Out:
# ...
#      ---------------------------------------- 13.0/13.0 MB 1.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.3/2.3 MB 16.1 MB/s eta 0:00:00
# ...
#      --------------------------------------- 38.8/38.8 MB 10.5 MB/s eta 0:00:00
# ...
#      --------------------------------------- 14.0/14.0 MB 13.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 313.2/313.2 kB 9.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 14.7 MB/s eta 0:00:00
# ...
#   Created wheel for myqr: filename=MyQR-2.3.1-py3-none-any.whl size=16703 sha256=6e4467a7961bfa51eb92e0bda46296db797ffeb3f4defa86cd945686780adc69
#   Stored in directory: c:\users\miche\appdata\local\pip\cache\wheels\10\72\47\e96d082352d5e4a48278d79b3189472e251d9eedb6166678b8
# Successfully built myqr
# ...

# %%
import robomaster
from robomaster import robot

# %% [markdown]
# Connect your laptop WiFi to the Robomaster directly.

# %%
# robomaster.config.LOCAL_IP_STRING = "192.168.1.144"

# Initialize robot.
ep_robot = robot.Robot()
ep_robot.initialize(conn_type='ap')

ep_version = ep_robot.get_version()
print("Robot Version: {0}".format(ep_version))

ep_led = ep_robot.led

# %%
robotic_arm_ctrl.recenter()

# %%
from robomaster import robotic_arm
robotic_arm_ctrl = robotic_arm.RoboticArm()
robotic_arm_ctrl.moveto(40, 50, wait_for_complete=True)
robotic_arm_ctrl.recenter()

# %%
ep_robot.close()
