# %%
from ugot import ugot
import time

got = ugot.UGOT()

got.initialize('192.168.1.235')
# got.show_light_rgb_effect(0, 225,0,3)
got.turn_off_lights()
# Out:
# 192.168.1.235:50051

# %%
print('hi') # string
 print("hi") # also a string
# Out:
#   Cell In[23], line 2
#     print("hi") # also a string
#     ^
# IndentationError: unexpected indent

# %%
if 10 < 11:
  print("ten is less than eleven") # tab to indent
# Out:
# ten is less than eleven
# ten is less than eleven

# %%
print('hi \nhi') # \n is newline
# Out:
# hi
# hi

# %%
# comments
# print('hi')
'''hello
hi
f
'''
# Out:
# 'hello\nhi\nf\n'

# %%
name = "Michelle"
age = "100"

# print("Hi, my name is", "Michelle")
print("Hi, my name is", name)
print("I am", age, "years old.")
print("I am " + age + " years old.")
# Out:
# Hi, my name is Michelle
# I am 100 years old.
# I am 100 years old.

# %%
# introduce yourself in a single print statement, each sentence is a new line
# say your name, age, and hobby
name = "Michelle"
age = "100"
hobby = "reading"
print("My name is " + name + "\nMy age is " + age + "\nMy hobby is " + hobby)
# Out:
# My name is Michelle
# My age is 100
# My hobby is reading

# %%
name = input("What is your name?")
print("Hi, my name is", name)
got.play_audio_tts("Hello "+ name)


# do the same thing for age and hobby
# Out:
# What is your name? Michelle
# Hi, my name is Michelle

# %%
age = 20
got.play_audio_tts(f"You are {age}")

# %%
print("Let's create a silly sentence.")
animal = input("Enter an animal: ")
color = input("Enter an color: ")

sentence = "Once upon a time, a " + color + " " + animal + " lived in Singapore and played Roblox."

print(sentence)
got.play_audio_tts(sentence)
# Out:
# Let's create a silly sentence.
# Enter an animal:  dog
# Enter an color:  blue
# Once upon a time, a blue dog lived in Singapore and played Roblox.
