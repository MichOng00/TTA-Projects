# %% [markdown]
# ## Session 2

# %% [markdown]
# 1. Array

# %%
array1 = [1,2,3,4,5,6]  # array demands the same data type for items
print(array1)
print(type(array1))
# Out:
# [1, 2, 3, 4, 5, 6]
# <class 'list'>

# %% [markdown]
# 2. Array in Numpy

# %%
import numpy as np
# 1D array
array1d = np.array([1,2,3,4,5,6])
print(f"1D Array:{array1d}")
print(f"Shape:{array1d.shape}")
print(type(array1d))
# Out:
# 1D Array:[1 2 3 4 5 6]
# Shape:(6,)
# <class 'numpy.ndarray'>

# %%
# 2D array
array2d=np.array([[1,2,3],
                  [4,5,6]])
print(f"2D Array:\n{array2d}")
print(f"Shape:{array2d.shape}")
print(type(array2d))
# Out:
# 2D Array:
# [[1 2 3]
#  [4 5 6]]
# Shape:(2, 3)
# <class 'numpy.ndarray'>

# %%
# 3D array
array3d=np.array([[[255,0,0],[0,255,0],[0,0,255]],
                  [[0,0,255],[0,255,0],[255,0,0]]])
print(f"3D Array:\n{array3d}")
print(f"Shape:{array3d.shape}")
print(type(array3d))
# Out:
# 3D Array:
# [[[255   0   0]
#   [  0 255   0]
#   [  0   0 255]]
#
#  [[  0   0 255]
#   [  0 255   0]
#   [255   0   0]]]
# Shape:(2, 3, 3)
# <class 'numpy.ndarray'>

# %%
Image("Array.png")

# %% [markdown]
# 3. UGOT image display

# %%
# Step 1: turn on the camera
got.open_camera()
print("The camera is on.")

# Step 2: get the raw data
picture = got.read_camera_data()
print(f"The raw data:{picture}")
print(f"Data type:{type(picture)}")

# Step 3: unpack the raw data, bytes to 1D array
picture=np.frombuffer(picture,np.uint8)
print(f"The data:{picture}")
print(f"Shape:{picture.shape}")
print(f"Data type:{type(picture)}")

# Step 4: 1D array to 3D array
picture =cv2.imdecode(picture,cv2.IMREAD_COLOR)
print(f"The data:{picture}")
print(f"Shape:{picture.shape}")
print(f"Data type:{type(picture)}")

#Step 5: pack the 3D array for Jupyter
ok,picture_jpg = cv2.imencode(".jpg",picture)
print(f"The data:{picture}")
print(f"Shape:{picture.shape}")
print(f"Data type:{type(picture)}")

#Step 6; shwo the image on screen
display(Image(picture_jpg.tobytes()))
# Out:
# The camera is on.
# The raw data:b'\xff\xd8\xff\xdb\x00C\x00\t\x05\x06\x07\x06\x05\t\x07\x06\x07\n\t\t\n\r\x16\x0e\r\x0c\x0c\r\x1b\x13\x14\x0f\x16 \x1c!!\x1f\x1c\x1f\x1e$(3+$&0&\x1e\x1f-<-0479:9"*?C?8C3897\xff\xdb\x00C\x01\t\n\n\r\x0b\r\x19\x0e\x0e\x197%\x1f%77777777777777777777777777777777777777777777777777\xff\xc0\x00\x11\x08\x01\xe0\x02\x80\x03\x01!\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz(\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\x
\nPh\x01h\xa0\x034\xb4\x00R\xd0\x02\xe7\x9a3@\x06ih\x00\xa5\xa0\x00R\xd0\x01E\x00\x19\xa2\x80\x0c\xd2\x8a\x00ZZ\x00(\xa0\x05\xa2\x80\n2h\x01\xd4R`\x7f\xff\xd4\xf4**\x8a\nJ\x00(\xa0\x02\x8a\x00(\xa0\x02\x8a\x00(\xcd\x00\x14P\x00h\xa0\x02\x90\xd0 \xa2\x80\n(\x01\t\xa0\x9a\x00J(\x004\x94\x00Q@\x01\xa4\xa0\x044\x94\x00RP\x027J ...
# Data type:<class 'bytes'>
# The data:[255 216 255 ... 255 255 217]
# Shape:(18962,)
# Data type:<class 'numpy.ndarray'>
# The data:[[[209 203 208]
#   [209 203 208]
#   [209 203 208]
#   ...
#   [165 166 156]
#   [165 166 156]
#   [165 166 156]]
#
#  [[209 203 208]
#   [209 203 208]
#   [209 203 208]
#   ...
#   [165 166 156]
#   [165 166 156]
#   [165 166 156]]
#
#  [[209 203 208]
#   [209 203 208]
#   [209 203 208]
#   ...
#   [165 166 156]
#   [165 166 156]
#   [165 166 156]]
#
#  ...
#
#  [[214 210 221]
#   [214 210 221]
#   [214 210 221]
#   ...
#   [243 240 242]
#   [243 240 242]
#   [243 240 242]]
#
#  [[214 210 221]
#   [214 210 221]
#   [214 210 221]
#   ...
#   [243 240 242]
#   [243 240 242]
#   [243 240 242]]
#
#  [[214 210 221]
#   [214 210 221]
#   [214 210 221]
#   ...
#   [243 240 242]
#   [243 240 242]
#   [243 240 242]]]
# Shape:(480, 640, 3)
# Data type:<class 'numpy.ndarray'>
# The data:[[[209 203 208]
#   [209 203 208]
#   [209 203 208]
#   ...
#   [165 166 156]
#   [165 166 156]
#   [165 166 156]]
#
#  [[209 203 208]
#   [209 203 208]
#   [209 203 208]
#   ...
#   [165 166 156]
#   [165 166 156]
#   [165 166 156]]
#
#  [[209 203 208]
#   [209 203 208]
#   [209 203 208]
#   ...
#   [165 166 156]
#   [165 166 156]
#   [165 166 156]]
#
#  ...
#
#  [[214 210 221]
#   [214 210 221]
#   [214 210 221]
#   ...
#   [243 240 242]
#   [243 240 242]
#   [243 240 242]]
#
#  [[214 210 221]
#   [214 210 221]
#   [214 210 221]
#   ...
#   [243 240 242]
#   [243 240 242]
#   [243 240 242]]
#
#  [[214 210 221]
#   [214 210 221]
#   [214 210 221]
#   ...
#   [243 240 242]
#   [243 240 242]
#   [243 240 242]]]
# Shape:(480, 640, 3)
# Data type:<class 'numpy.ndarray'>

# %%
from IPython.display import Image, display

# %%
Image("Robot camera to image-2.png")

# %%
import numpy as np
import cv2
from IPython.display import Image, display

from ugot import ugot
got = ugot.UGOT()
got.initialize("192.168.1.236")

got.open_camera()

picture = got.read_camera_data()

picture=np.frombuffer(picture,np.uint8)

picture =cv2.imdecode(picture,cv2.IMREAD_COLOR)

ok,picture_jpg = cv2.imencode(".jpg",picture)

display(Image(picture_jpg.tobytes()))
# Out:
# 192.168.1.236:50051
